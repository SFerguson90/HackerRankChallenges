# %%
# 21/23 Test Cases Passed... missing two :\

import os
import sys


def gameWithCells(n, m):
    
    if m == 1 and n == 1:
        answer = 1
        return int(answer)
    elif m == 0 or n == 0:
        answer = 0
        return int(answer)
    elif m == 1 and n%2 == 0:
        answer = n/2
        return int(answer)
    elif m == 1 and n%2 == 1:
        answer = (n/2) + 1
        return int(answer)
    elif n == 1 and m%2 == 1:
        answer = (m/2) + 1
    elif n == 1 and m%2 == 0:
        answer = m/2
        return int(answer)
    elif n%2 == 0 and m%2 == 0:
        answer = (n*m)/4
        return int(answer)
    elif n%2 == 1 and m%2 == 0:
        y = n-1
        subAnswer = (y*m)/4
        leftOver = m/2
        answer = subAnswer + leftOver
        return int(answer)
    elif n%2 == 0 and m%2 == 1:
        x = m-1
        subAnswer = (x*n)/4
        leftOver = n/2
        answer = subAnswer + leftOver
        return int(answer)
    elif n%2 == 1 and m%2 == 1:
        x = n-1
        y = m-1
        subAnswer = (x*y)/4
        leftOver1 = (n-1)/2
        leftOver2 = (m-1)/2
        answer = subAnswer + leftOver1 + leftOver2 + 1
        return int(answer)
    

if __name__ == '__main__':
    
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    nm = input().split()

    n = int(nm[0])

    m = int(nm[1])

    result = gameWithCells(n, m)

    fptr.write(str(result) + '\n')

    fptr.close()
